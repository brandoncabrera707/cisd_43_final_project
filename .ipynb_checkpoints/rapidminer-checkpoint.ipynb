# %% [markdown]
# RapidMiner portion of the final project. I choose to use a KNN model and did a confusion matrix to evaluate performance

# %% [markdown]
# ![RapidMiner_design_workflow.jpeg](attachment:1c9940bc-e382-46f5-b8c0-fe373d09c615.jpeg)

# %% [markdown]
# Confusion Matrix results

# %% [markdown]
# ![RapidMiner_confusion_matrix.jpeg](attachment:086586d8-66fc-495c-a50f-605ff0d3ceba.jpeg)

# %% [markdown]
# This model performed better than the one trained in the main.ipynb file. This model used n_neighbors = 5 where as the other one used n_neighbors = 6.
